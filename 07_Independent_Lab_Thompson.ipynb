# %% [markdown]
# # Independent Lab: Manipulating Data
#
# **Intro to Python**
# **Manipulating Data**
# **Cody Thompson**
# **Date:** 4/14/2025
#
# Welcome to my notebook for the Manipulating Data lab! In this notebook, I will be working with two datasets: `CaliforniaHospitalData.csv` and `CaliforniaHospitalData_Personnel.txt`. My task is to pre-process and clean the data, merge the two datasets, filter and rename columns, and perform various data manipulations to prepare the data for analysis by the Business Intelligence team.

# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold

# Set Working Directory
os.chdir('C:\\Users\\cthom\\Downloads\\BGEN 632 Intro to Python\\GitHub_Repos\\Week 7\\week7labs\\data')

# Verify the current working directory
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\cthom\Downloads\BGEN 632 Intro to Python\GitHub_Repos\Week 7\week7labs\data

# %%
# Load the hospital data into a DataFrame
hospital_df = pd.read_csv('CaliforniaHospitalData.csv')

# Load the personnel data into a DataFrame
personnel_df = pd.read_csv('CaliforniaHospitalData_Personnel.txt', delimiter='\t')

# %%
# Display the first few rows of both DataFrames to verify the correct loading
hospital_df.head()
# Out:
#    HospitalID                              Name         Zip  \
# 0       45740                  Mammoth Hospital  93546-0660
# 1       12145  Victor Valley Community Hospital       92392
# 2       25667        Pioneers Memorial Hospital       92227
# 3       46996      Ridgecrest Regional Hospital       93555
# 4       37393        Barstow Community Hospital       92311
#
#                    Website TypeControl     Teaching DonorType  NoFTE  \
# 0  www.mammothhospital.com    District  Small/Rural   Charity  327.0
# 1             www.vvch.org  Non Profit  Small/Rural   Charity  345.0
# 2             www.pmhd.org    District  Small/Rural   Charity  601.2
# 3              www.rrh.org  Non Profit  Small/Rural   Charity  400.0
# 4  www.barstowhospital.com    Investor  Small/Rural   Charity  262.0
#
#      NetPatRev    InOperExp   OutOperExp   OperRev   OperInc  AvlBeds
# 0  135520.2186  20523425.53  34916220.47  49933713  -5505933       15
# 1  136156.6913  33447542.78  20348596.22  53351748   -444391       99
# 2  197094.2541  37254178.67  37832448.33  72933707  -2152920      107
# 3  139170.3798  23385570.10  24661355.90  51087341   3040415       55
# 4  116797.8306  13684502.49  15159986.51  42845642  14001153       42

# %%
# Display the first few rows of both DataFrames to verify the correct loading
personnel_df.head()
# Out:
#    HospitalID  Work_ID   LastName FirstName Gender  PositionID  \
# 0       35665   351131  Cherukuri    Dileep      M           4
# 1       12145   756481  Rodriguez      Jose      M           1
# 2       45771   756481  Rodriguez      Jose      M           1
# 3       43353   756481  Rodriguez      Jose      M           4
# 4       17718   811240    Charles   Kenneth      M           1
#
#               PositionTitle  Compensation  MaxTerm StartDate         Phone  \
# 0  Safety Inspection Member         23987        2  1/1/2019  405-564-5580
# 1   Regional Representative         46978        4  1/1/2009  405-744-2238
# 2   Regional Representative         46978        4  1/1/2011  405-744-2238
# 3  Safety Inspection Member         23987        2  1/1/2011  405-744-2238
# 4   Regional Representative         46978        4  1/1/2009  405-744-3412
#
#                            Email
# 0   dileep.cherukuri@okstate.edu
# 1   jose.rodriguez@edihealth.com
# 2   jose.rodriguez@edihealth.com
# 3   jose.rodriguez@edihealth.com
# 4  kenneth.charles@edihealth.com

# %%
# Merge the hospital and personnel data on the 'HospitalID' column
merged_df = pd.merge(hospital_df, personnel_df, on='HospitalID', how='inner')

# Remove unnecessary columns
merged_df.drop(columns=['Work_ID', 'PositionID', 'Website'], inplace=True)

# Display the first few rows of the merged DataFrame
merged_df.head()
# Out:
#    HospitalID                              Name         Zip TypeControl  \
# 0       45740                  Mammoth Hospital  93546-0660    District
# 1       12145  Victor Valley Community Hospital       92392  Non Profit
# 2       25667        Pioneers Memorial Hospital       92227    District
# 3       46996      Ridgecrest Regional Hospital       93555  Non Profit
# 4       37393        Barstow Community Hospital       92311    Investor
#
#       Teaching DonorType  NoFTE    NetPatRev    InOperExp   OutOperExp  ...  \
# 0  Small/Rural   Charity  327.0  135520.2186  20523425.53  34916220.47  ...
# 1  Small/Rural   Charity  345.0  136156.6913  33447542.78  20348596.22  ...
# 2  Small/Rural   Charity  601.2  197094.2541  37254178.67  37832448.33  ...
# 3  Small/Rural   Charity  400.0  139170.3798  23385570.10  24661355.90  ...
# 4  Small/Rural   Charity  262.0  116797.8306  13684502.49  15159986.51  ...
#
#    AvlBeds   LastName  FirstName Gender             PositionTitle  \
# 0       15        Web      David      M  Safety Inspection Member
# 1       99  Rodriguez       Jose      M   Regional Representative
# 2      107    Adamson      David      M   Regional Representative
# 3       55    Roberts    Melissa      F  Safety Inspection Member
# 4       42      Iwata      Akira      M   Regional Representative
#
#   Compensation MaxTerm  StartDate         Phone                         Email
# 0        23987       2   1/1/2012  785-532-2452     david.web@comenitymed.com
# 1        46978       4   1/1/2009  405-744-2238  jose.rodriguez@edihealth.com
# 2        46978       4   1/1/2012  785-532-7573    david.adamson@txbiomed.net
# 3        23987       2   1/1/2009  785-532-9779  melissa.roberts@txbiomed.net
# 4        46978       4   1/1/2011  801-611-9161           akira.iwata@hsu.edu
#
# [5 rows x 22 columns]

# %%
# Exporting the Data
# Ensure the 'data' directory exists, create it if not
if not os.path.exists('data'):
    os.makedirs('data')

# Filter the data based on the specified conditions (using merged_df, not hospital_df)
filtered_df = merged_df[(merged_df['Teaching'] == 'Small/Rural') &  # Small/Rural hospitals
                        (merged_df['AvlBeds'] >= 15) &  # At least 15 available beds
                        (merged_df['OperInc'] >= 0)]  # Non-negative operating income

# Export the filtered data to a tab-delimited file
filtered_df.to_csv('data/hospital_data_new.txt', sep='\t', index=False)

# Verify the export was successful
print('hospital_data_new.txt exported successfully!')

# Display the first few rows to confirm the data
filtered_df.head()
# Out:
# hospital_data_new.txt exported successfully!
#    HospitalID                              Name         Zip TypeControl  \
# 3       46996      Ridgecrest Regional Hospital       93555  Non Profit
# 4       37393        Barstow Community Hospital       92311    Investor
# 5       17741  St. Elizabeth Community Hospital       96080  Non Profit
# 6       20277       Ukiah Valley Medical Center       95482  Non Profit
# 8       29823    Colusa Regional Medical Center  95932-2954  Non Profit
#
#       Teaching DonorType  NoFTE    NetPatRev     InOperExp   OutOperExp  ...  \
# 3  Small/Rural   Charity  400.0  139170.3798  2.338557e+07  24661355.90  ...
# 4  Small/Rural   Charity  262.0  116797.8306  1.368450e+07  15159986.51  ...
# 5  Small/Rural   Charity  397.5  232503.0191  3.668289e+07  36739260.30  ...
# 6  Small/Rural   Charity  503.5  214516.4481  3.270922e+07  43571851.35  ...
# 8  Small/Rural   Charity  168.0   51726.4918  9.022366e+06  10402509.55  ...
#
#    AvlBeds  LastName  FirstName Gender             PositionTitle Compensation  \
# 3       55   Roberts    Melissa      F  Safety Inspection Member        23987
# 4       42     Iwata      Akira      M   Regional Representative        46978
# 5       66    Marlin       Bill      M  Safety Inspection Member        23987
# 6       65  Johanson      Sandy      F   Regional Representative        46978
# 8       48    Tanner   Patricia      F           Acting Director       248904
#
#   MaxTerm  StartDate         Phone                          Email
# 3       2   1/1/2009  785-532-9779   melissa.roberts@txbiomed.net
# 4       4   1/1/2011  801-611-9161            akira.iwata@hsu.edu
# 5       2   1/1/2011  503-645-7508        bill.marlin@larcmed.com
# 6       4   1/1/2012  801-216-4821         sandy.johanson@ihc.com
# 8       8   1/1/2009  801-687-7877  patricia.tanner@prohealth.net
#
# [5 rows x 22 columns]

# %%
# Load the newly created file into a new DataFrame
filtered_df = pd.read_csv('data/hospital_data_new.txt', sep='\t')

# Rename the specified columns
filtered_df.rename(columns={
    'NoFTE': 'FullTimeCount',
    'NetPatRev': 'NetPatientRevenue',
    'InOperExp': 'InpatientOperExp',
    'OutOperExp': 'OutpatientOperExp',
    'OperRev': 'Operating_Revenue',
    'OperInc': 'Operating_Income'
}, inplace=True)

# Display the first 5 rows to confirm the renaming
print(filtered_df.head(5))
# Out:
#    HospitalID                              Name         Zip TypeControl  \
# 0       46996      Ridgecrest Regional Hospital       93555  Non Profit
# 1       37393        Barstow Community Hospital       92311    Investor
# 2       17741  St. Elizabeth Community Hospital       96080  Non Profit
# 3       20277       Ukiah Valley Medical Center       95482  Non Profit
# 4       29823    Colusa Regional Medical Center  95932-2954  Non Profit
#
#       Teaching DonorType  FullTimeCount  NetPatientRevenue  InpatientOperExp  \
# 0  Small/Rural   Charity          400.0        139170.3798      2.338557e+07
# 1  Small/Rural   Charity          262.0        116797.8306      1.368450e+07
# 2  Small/Rural   Charity          397.5        232503.0191      3.668289e+07
# 3  Small/Rural   Charity          503.5        214516.4481      3.270922e+07
# 4  Small/Rural   Charity          168.0         51726.4918      9.022366e+06
#
#    OutpatientOperExp  ...  AvlBeds  LastName  FirstName Gender  \
# 0        24661355.90  ...       55   Roberts    Melissa      F
# 1        15159986.51  ...       42     Iwata      Akira      M
# 2        36739260.30  ...       66    Marlin       Bill      M
# 3        43571851.35  ...       65  Johanson      Sandy      F
# 4        10402509.55  ...       48    Tanner   Patricia      F
#
#               PositionTitle Compensation MaxTerm  StartDate         Phone  \
# 0  Safety Inspection Member        23987       2   1/1/2009  785-532-9779
# 1   Regional Representative        46978       4   1/1/2011  801-611-9161
# 2  Safety Inspection Member        23987       2   1/1/2011  503-645-7508
# 3   Regional Representative        46978       4   1/1/2012  801-216-4821
# 4           Acting Director       248904       8   1/1/2009  801-687-7877
#
#                            Email
# 0   melissa.roberts@txbiomed.net
# 1            akira.iwata@hsu.edu
# 2        bill.marlin@larcmed.com
# 3         sandy.johanson@ihc.com
# 4  patricia.tanner@prohealth.net
#
# [5 rows x 22 columns]

# %%
# Insert New Records with all specified columns (including Phone and Email)

new_employee_1 = {
    'HospitalID': 46996,
    'Name': 'Ridgecrest Regional Hospital',
    'Zip': '93555',
    'TypeControl': 'Non Profit',
    'Teaching': 'Small/Rural',
    'DonorType': 'Charity',
    'FullTimeCount': 100,  
    'NetPatientRevenue': 50000, 
    'InpatientOperExp': 100000, 
    'OutpatientOperExp': 200000,
    'Operating_Revenue': 300000,
    'Operating_Income': 10000,  
    'AvlBeds': 50,
    'PositionTitle': 'Regional Representative',
    'Compensation': 46978,
    'MaxTerm': 4,
    'StartDate': '2025-04-14',
    'Gender': 'M',
    'LastName': 'Thompson',
    'FirstName': 'Cody',
    'Phone': '555-555-0101',  
    'Email': 'cody.thompson@example.com'  
}

new_employee_2 = {
    'HospitalID': 17741,
    'Name': 'St. Elizabeth Community Hospital',
    'Zip': '96080',  
    'TypeControl': 'Non Profit',
    'Teaching': 'Small/Rural',
    'DonorType': 'Charity',
    'FullTimeCount': 200,  
    'NetPatientRevenue': 70000,  
    'InpatientOperExp': 150000,  
    'OutpatientOperExp': 250000,  
    'Operating_Revenue': 350000,  
    'Operating_Income': 15000,  
    'AvlBeds': 60,
    'PositionTitle': 'State Board Representative',
    'Compensation': 89473,
    'MaxTerm': 3,
    'StartDate': '2025-04-14',
    'Gender': 'M',
    'LastName': 'Thompson',
    'FirstName': 'Cody',
    'Phone': '555-555-0102',  
    'Email': 'cody.thompson2@example.com'
}

# Convert the new records to DataFrames
new_employee_1_df = pd.DataFrame([new_employee_1])
new_employee_2_df = pd.DataFrame([new_employee_2])

# Concatenate the new records with the existing filtered_df
new_merge = pd.concat([filtered_df, new_employee_1_df, new_employee_2_df], ignore_index=True)

# Display the updated DataFrame to confirm the new records
new_merge.tail(10)
# Out:
#     HospitalID                                       Name         Zip  \
# 20       20266  Sonora Regional Medical Center - greenley       95370
# 21       37436                         Fallbrook Hospital       92028
# 22       17736            Sierra Nevada Memorial Hospital       95945
# 23       38802         Santa Ynez Valley Cottage Hospital       93463
# 24       45067                       Glenn Medical Center  95988-2745
# 25       28283                   Hi-Desert Medical Center       92252
# 26       28812               Oak Valley District Hospital       95361
# 27       19868             Ojai Valley Community Hospital  93023-3163
# 28       46996               Ridgecrest Regional Hospital       93555
# 29       17741           St. Elizabeth Community Hospital       96080
#
#    TypeControl     Teaching DonorType  FullTimeCount  NetPatientRevenue  \
# 20  Non Profit  Small/Rural   Charity          779.0       367540.66390
# 21    District  Small/Rural   Charity          501.0       108960.41800
# 22  Non Profit  Small/Rural   Charity          524.5       295579.23500
# 23  Non Profit  Small/Rural   Charity           67.0        28773.45355
# 24  Non Profit  Small/Rural   Charity          100.0        29712.33060
# 25    District  Small/Rural   Charity          451.5       145733.57650
# 26    District  Small/Rural   Charity          503.0       137280.71040
# 27  Non Profit  Small/Rural   Charity          180.0        59504.62295
# 28  Non Profit  Small/Rural   Charity          100.0        50000.00000
# 29  Non Profit  Small/Rural   Charity          200.0        70000.00000
#
#     InpatientOperExp  OutpatientOperExp  ...  AvlBeds  LastName  FirstName  \
# 20      6.822885e+07       6.996886e+07  ...      152     Adams      Sandy
# 21      2.300169e+07       1.472747e+07  ...      146  Johanson      Sandy
# 22      5.669283e+07       5.026417e+07  ...      121   Charles    Kenneth
# 23      1.780969e+06       8.235088e+06  ...       20      Dong    HongWei
# 24      2.076879e+06       9.501695e+06  ...       15   Adamson      David
# 25      3.184268e+07       2.118493e+07  ...      179     Smith      Frank
# 26      1.949562e+07       2.984690e+07  ...      150    Holmes      Holly
# 27      1.195530e+07       1.032680e+07  ...      103   Coulter      Tracy
# 28      1.000000e+05       2.000000e+05  ...       50  Thompson       Cody
# 29      1.500000e+05       2.500000e+05  ...       60  Thompson       Cody
#
#    Gender               PositionTitle Compensation MaxTerm   StartDate  \
# 20      F     Regional Representative        46978       4    1/1/2009
# 21      F  State Board Representative        89473       3    1/1/2012
# 22      M             Acting Director       248904       8    1/1/2006
# 23      F     Regional Representative        46978       4    1/1/2010
# 24      M    Safety Inspection Member        23987       2    1/1/2012
# 25      M             Acting Director       248904       8    1/1/2005
# 26      F             Acting Director       248904       8    1/1/2003
# 27      F     Regional Representative        46978       4    1/1/2010
# 28      M     Regional Representative        46978       4  2025-04-14
# 29      M  State Board Representative        89473       3  2025-04-14
#
#            Phone                          Email
# 20  785-532-3333    sandy.adams@comenitymed.com
# 21  801-216-4821         sandy.johanson@ihc.com
# 22  405-744-3412  kenneth.charles@edihealth.com
# 23  479-354-4864  hongwei.dong@brokenhealth.com
# 24  785-532-7573     david.adamson@txbiomed.net
# 25  405-744-5687      frank.smith@edihealth.com
# 26  785-532-4515           holly.holmes@asu.edu
# 27  785-532-6548          tracy.coulter@wou.edu
# 28  555-555-0101      cody.thompson@example.com
# 29  555-555-0102     cody.thompson2@example.com
#
# [10 rows x 22 columns]

# %%
# Filtering Data
# Task 1: Select all hospitals that are non-profit with more than 250 employees, unless the net patient revenue is smaller than $109,000.
# Also, remove the columns containing employee information (e.g., PositionTitle, Compensation, etc.)

# Filter hospitals that meet the conditions
filtered_non_profit_hospitals = new_merge[(new_merge['TypeControl'] == 'Non Profit') &  # Non-profit hospitals
                                          (new_merge['FullTimeCount'] > 250) &  # More than 250 employees
                                          (new_merge['NetPatientRevenue'] >= 109000)]  # Net patient revenue >= $109,000


# Display the result for Task 1
print("Filtered Non-Profit Hospitals with more than 250 employees:")
filtered_non_profit_hospitals.head()
# Out:
# Filtered Non-Profit Hospitals with more than 250 employees:
#    HospitalID                              Name         Zip TypeControl  \
# 0       46996      Ridgecrest Regional Hospital       93555  Non Profit
# 2       17741  St. Elizabeth Community Hospital       96080  Non Profit
# 3       20277       Ukiah Valley Medical Center       95482  Non Profit
# 5       13738           St. Mary Medical Center  92307-2206  Non Profit
# 6       38798    Goleta Valley Cottage Hospital       93111  Non Profit
#
#       Teaching DonorType  FullTimeCount  NetPatientRevenue  InpatientOperExp  \
# 0  Small/Rural   Charity          400.0        139170.3798      2.338557e+07
# 2  Small/Rural   Charity          397.5        232503.0191      3.668289e+07
# 3  Small/Rural   Charity          503.5        214516.4481      3.270922e+07
# 5  Small/Rural   Charity         1216.0        540975.1175      1.251283e+08
# 6  Small/Rural   Charity          288.0        335179.5574      5.358904e+07
#
#    OutpatientOperExp  ...  AvlBeds  LastName  FirstName Gender  \
# 0        24661355.90  ...       55   Roberts    Melissa      F
# 2        36739260.30  ...       66    Marlin       Bill      M
# 3        43571851.35  ...       65  Johanson      Sandy      F
# 5        66801544.65  ...      186   Milgrom   Patricia      F
# 6        67030147.91  ...      119     Iwata      Akira      M
#
#               PositionTitle Compensation MaxTerm  StartDate         Phone  \
# 0  Safety Inspection Member        23987       2   1/1/2009  785-532-9779
# 2  Safety Inspection Member        23987       2   1/1/2011  503-645-7508
# 3   Regional Representative        46978       4   1/1/2012  801-216-4821
# 5  Safety Inspection Member        23987       2   1/1/2011  479-178-9584
# 6   Regional Representative        46978       4   1/1/2011  801-611-9161
#
#                                Email
# 0       melissa.roberts@txbiomed.net
# 2            bill.marlin@larcmed.com
# 3             sandy.johanson@ihc.com
# 5  patricia.milgrom@brokenhealth.com
# 6                akira.iwata@hsu.edu
#
# [5 rows x 22 columns]

# %%
# Select all the *Regional Representatives* who work at a hospital with operating income greater than $100,000.
# Filter Regional Representatives with Operating Income > $100,000

filtered_regional_representatives = new_merge[(new_merge['PositionTitle'] == 'Regional Representative') &  # Regional Representatives
                                              (new_merge['Operating_Income'] > 100000)]  # Operating Income > $100,000

# Display the result for Task 2
print("\nFiltered Regional Representatives with Operating Income > $100,000:")
filtered_regional_representatives.head()
# Out:
# Filtered Regional Representatives with Operating Income > $100,000:
#     HospitalID                                 Name    Zip TypeControl  \
# 1        37393           Barstow Community Hospital  92311    Investor
# 3        20277          Ukiah Valley Medical Center  95482  Non Profit
# 6        38798       Goleta Valley Cottage Hospital  93111  Non Profit
# 7        46348             Barton Memorial Hospital  96150  Non Profit
# 10       17718  Mercy Medical Center - Mount Shasta  96067  Non Profit
#
#        Teaching DonorType  FullTimeCount  NetPatientRevenue  InpatientOperExp  \
# 1   Small/Rural   Charity          262.0        116797.8306       13684502.49
# 3   Small/Rural   Charity          503.5        214516.4481       32709222.65
# 6   Small/Rural   Charity          288.0        335179.5574       53589036.09
# 7   Small/Rural   Charity          750.0        335179.5574       53589036.09
# 10  Small/Rural   Charity          215.5        123480.2705       22003500.15
#
#     OutpatientOperExp  ...  AvlBeds  LastName  FirstName Gender  \
# 1         15159986.51  ...       42     Iwata      Akira      M
# 3         43571851.35  ...       65  Johanson      Sandy      F
# 6         67030147.91  ...      119     Iwata      Akira      M
# 7         67030147.91  ...      119    Paanua    Kaaluai      M
# 10        22410053.85  ...       60   Charles    Kenneth      M
#
#               PositionTitle Compensation MaxTerm  StartDate         Phone  \
# 1   Regional Representative        46978       4   1/1/2011  801-611-9161
# 3   Regional Representative        46978       4   1/1/2012  801-216-4821
# 6   Regional Representative        46978       4   1/1/2011  801-611-9161
# 7   Regional Representative        46978       4   1/1/2011  479-684-1883
# 10  Regional Representative        46978       4   1/1/2009  405-744-3412
#
#                               Email
# 1               akira.iwata@hsu.edu
# 3            sandy.johanson@ihc.com
# 6               akira.iwata@hsu.edu
# 7   kaaluai.paanua@brokenhealth.com
# 10    kenneth.charles@edihealth.com
#
# [5 rows x 22 columns]

# %%
# Convert 'StartDate' column to datetime
new_merge['StartDate'] = pd.to_datetime(new_merge['StartDate'])

# Confirm the conversion by outputting the data types of all columns
print("Data Types after Conversion:")
print(new_merge.dtypes)

# Display the first 5 records of the 'StartDate' column to confirm the conversion
print("\nFirst 5 records of the 'StartDate' column:")
print(new_merge['StartDate'].head())
# Out:
# Data Types after Conversion:
# HospitalID                    int64
# Name                         object
# Zip                          object
# TypeControl                  object
# Teaching                     object
# DonorType                    object
# FullTimeCount               float64
# NetPatientRevenue           float64
# InpatientOperExp            float64
# OutpatientOperExp           float64
# Operating_Revenue             int64
# Operating_Income              int64
# AvlBeds                       int64
# LastName                     object
# FirstName                    object
# Gender                       object
# PositionTitle                object
# Compensation                  int64
# MaxTerm                       int64
# StartDate            datetime64[ns]
# Phone                        object
# Email                        object
# dtype: object
#
# First 5 records of the 'StartDate' column:
# 0   2009-01-01
# 1   2011-01-01
# 2   2011-01-01
# 3   2012-01-01
# 4   2009-01-01
# Name: StartDate, dtype: datetime64[ns]
